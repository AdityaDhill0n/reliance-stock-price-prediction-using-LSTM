# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('reliance_data.csv')

# %%
df
# Out:
#             Date    Symbol Series  Prev Close     Open     High      Low  \
# 0     01-01-1996  RELIANCE     EQ      204.65   205.00   206.10   203.65
# 1     02-01-1996  RELIANCE     EQ      205.75   205.25   206.25   202.65
# 2     03-01-1996  RELIANCE     EQ      204.15   207.50   216.95   205.25
# 3     04-01-1996  RELIANCE     EQ      205.70   203.75   204.40   201.05
# 4     05-01-1996  RELIANCE     EQ      203.80   203.00   203.00   200.65
# ...          ...       ...    ...         ...      ...      ...      ...
# 6200  23-11-2020  RELIANCE     EQ     1899.50  1951.00  1970.00  1926.25
# 6201  24-11-2020  RELIANCE     EQ     1950.70  1964.00  1974.00  1932.00
# 6202  25-11-2020  RELIANCE     EQ     1964.05  1980.00  1992.95  1942.20
# 6203  26-11-2020  RELIANCE     EQ     1947.80  1953.05  1965.00  1930.05
# 6204  27-11-2020  RELIANCE     EQ     1952.60  1940.50  1956.10  1921.40
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# 0         NaN   205.75   205.26   3717450  7.630000e+13       NaN
# 1         NaN   204.15   204.13   6024650  1.230000e+14       NaN
# 2         NaN   205.70   207.04   7473500  1.550000e+14       NaN
# 3         NaN   203.80   202.47   7744000  1.570000e+14       NaN
# 4         NaN   202.40   202.05   5952000  1.200000e+14       NaN
# ...       ...      ...      ...       ...           ...       ...
# 6200  1955.20  1950.70  1952.18  20918665  4.083700e+15  497781.0
# 6201  1971.05  1964.05  1952.11  14277083  2.787040e+15  362587.0
# 6202  1947.50  1947.80  1969.06  15062376  2.965870e+15  356793.0
# 6203  1957.00  1952.60  1946.67  11924527  2.321310e+15  266412.0
# 6204  1940.50  1929.80  1935.45  21845931  4.228160e+15  314085.0
#
#       Deliverable Volume  %Deliverble
# 0                    NaN          NaN
# 1                    NaN          NaN
# 2                    NaN          NaN
# 3                    NaN          NaN
# 4                    NaN          NaN
# ...                  ...          ...
# 6200           5148955.0       0.2461
# 6201           3213843.0       0.2251
# 6202           3040444.0       0.2019
# 6203           3406506.0       0.2857
# 6204          12489338.0       0.5717
#
# [6205 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6205 entries, 0 to 6204
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                6205 non-null   object
#  1   Symbol              6205 non-null   object
#  2   Series              6205 non-null   object
#  3   Prev Close          6205 non-null   float64
#  4   Open                6205 non-null   float64
#  5   High                6205 non-null   float64
#  6   Low                 6205 non-null   float64
#  7   Last                5657 non-null   float64
#  8   Close               6205 non-null   float64
#  9   VWAP                6205 non-null   float64
#  10  Volume              6205 non-null   int64
#  11  Turnover            6205 non-null   float64
#  12  Trades              2356 non-null   float64
#  13  Deliverable Volume  4693 non-null   float64
#  14  %Deliverble         4693 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 727.3+ KB

# %% [markdown]
# Columns: Last, Trades, Deliverable Volume, %Deliverables have missing values

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  6205.000000  6205.000000  6205.000000  6205.000000  5657.000000
# mean    864.978445   866.381176   878.763811   852.795649   925.596986
# std     588.711275   590.165211   599.625939   578.473998   581.604138
# min       0.000000   102.600000   105.600000    99.600000   101.600000
# 25%     335.200000   335.000000   340.700000   329.500000   437.550000
# 50%     850.650000   852.500000   862.000000   842.100000   892.350000
# 75%    1089.400000  1091.100000  1107.000000  1073.950000  1129.900000
# max    3220.850000  3298.000000  3298.000000  3141.300000  3223.000000
#
#              Close         VWAP        Volume      Turnover        Trades  \
# count  6205.000000  6205.000000  6.205000e+03  6.205000e+03  2.356000e+03
# mean    865.291289   865.851146  6.215219e+06  5.187662e+14  1.383690e+05
# std     588.763023   588.941488  5.479271e+06  7.539147e+14  1.260736e+05
# min     101.300000   101.840000  5.282000e+04  3.480000e+12  2.991000e+03
# 25%     335.350000   335.710000  3.021751e+06  1.840000e+14  7.119900e+04
# 50%     850.700000   851.680000  4.602904e+06  3.270000e+14  9.841550e+04
# 75%    1089.850000  1089.480000  7.304408e+06  5.730000e+14  1.559778e+05
# max    3220.850000  3197.750000  6.523089e+07  1.473430e+16  1.428490e+06
#
#        Deliverable Volume  %Deliverble
# count        4.693000e+03  4693.000000
# mean         2.239901e+06     0.436332
# std          1.861021e+06     0.145526
# min          2.909700e+04     0.076300
# 25%          1.178486e+06     0.323000
# 50%          1.784092e+06     0.452300
# 75%          2.685974e+06     0.546300
# max          3.495888e+07     0.978300

# %% [markdown]
# # converting the date column to datetime

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '30-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '31-01-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-02-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-03-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '30-04-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '30-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '31-05-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-06-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '30-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '31-07-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '30-08-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '30-09-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '31-10-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-11-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-12-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-12-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-12-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-12-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-12-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-12-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-12-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-12-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-12-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '31-12-1996' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '30-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '31-01-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-02-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-03-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-03-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-03-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-03-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-03-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-03-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-03-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-03-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-03-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-03-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '31-03-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-04-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-04-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-04-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-04-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-04-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-04-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-04-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-04-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-04-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '30-04-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-05-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-05-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-05-1997' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# ...
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '30-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '31-07-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '31-08-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '30-09-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '15-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '16-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '21-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '22-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '28-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '29-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '30-10-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '13-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '14-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '17-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '18-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '19-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '20-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '23-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '24-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '25-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '26-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\adi07\AppData\Local\Temp\ipykernel_22844\2394721818.py:1: UserWarning: Parsing '27-11-2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6205 entries, 0 to 6204
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                6205 non-null   datetime64[ns]
#  1   Symbol              6205 non-null   object
#  2   Series              6205 non-null   object
#  3   Prev Close          6205 non-null   float64
#  4   Open                6205 non-null   float64
#  5   High                6205 non-null   float64
#  6   Low                 6205 non-null   float64
#  7   Last                5657 non-null   float64
#  8   Close               6205 non-null   float64
#  9   VWAP                6205 non-null   float64
#  10  Volume              6205 non-null   int64
#  11  Turnover            6205 non-null   float64
#  12  Trades              2356 non-null   float64
#  13  Deliverable Volume  4693 non-null   float64
#  14  %Deliverble         4693 non-null   float64
# dtypes: datetime64[ns](1), float64(11), int64(1), object(2)
# memory usage: 727.3+ KB

# %% [markdown]
# # Checking for unique values in symbol and series columns

# %%
print('Total Unique values in Symbol are: ', df['Symbol'].nunique())
# Out:
# Total Unique values in Symbol are:  1

# %%
print("Total Unique values  in Series are: ", df['Series'].nunique())
# Out:
# Total Unique values  in Series are:  1

# %% [markdown]
# # Since both the columns have zero variance, we drop them

# %%
df = df.drop(['Symbol','Series'], axis = 1)

# %% [markdown]
# # Missing values analysis

# %%
missing_values  = df.isna().sum()

# %%
missing_values
# Out:
# Date                     0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                   548
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                3849
# Deliverable Volume    1512
# %Deliverble           1512
# dtype: int64

# %% [markdown]
# # In this Scenario, we have to in-depth analysis of each column displaying missing values, to understand what kind of treatment is required

# %%
sns.boxplot(df['Last'])
# Out:
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Last'>

# %% [markdown]
# # 'Last' column has outliers, in this context mean imputation is not applicable, so we can go with median imputation techniques

# %%
from sklearn.impute import SimpleImputer

SI = SimpleImputer(missing_values=np.nan, strategy='median')

df['Last'] = SI.fit_transform(df[['Last']])

# %% [markdown]
# # Now doing analysis for Trades column

# %%
sns.boxplot(df['Trades'])
# Out:
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Trades'>

# %% [markdown]
# # This column also has outliers

# %%
df['Trades'] = SI.fit_transform(df[['Trades']])

# %%
df.isna().sum()
# Out:
# Date                     0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                   0
# Deliverable Volume    1512
# %Deliverble           1512
# dtype: int64

# %% [markdown]
# # Now doing analysis for Deliverable Volume and %Deliverable, to see if its required to keep both the columns

# %%
corr = df.corr()

# %%
corr
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.999242  0.998930  0.998841  0.947332
# Open                  0.999242  1.000000  0.999580  0.999465  0.947985
# High                  0.998930  0.999580  1.000000  0.999245  0.948744
# Low                   0.998841  0.999465  0.999245  1.000000  0.947946
# Last                  0.947332  0.947985  0.948744  0.947946  1.000000
# Close                 0.998626  0.999152  0.999562  0.999580  0.948828
# VWAP                  0.999021  0.999553  0.999754  0.999754  0.948624
# Volume               -0.061675 -0.061579 -0.055612 -0.065601  0.039798
# Turnover              0.480997  0.481540  0.485931  0.478901  0.478973
# Trades                0.252551  0.253437  0.256610  0.251881  0.250220
# Deliverable Volume    0.149608  0.149648  0.153494  0.145969  0.149811
# %Deliverble           0.147684  0.147107  0.142298  0.151544  0.145808
#
#                        Close      VWAP    Volume  Turnover    Trades  \
# Prev Close          0.998626  0.999021 -0.061675  0.480997  0.252551
# Open                0.999152  0.999553 -0.061579  0.481540  0.253437
# High                0.999562  0.999754 -0.055612  0.485931  0.256610
# Low                 0.999580  0.999754 -0.065601  0.478901  0.251881
# Last                0.948828  0.948624  0.039798  0.478973  0.250220
# Close               1.000000  0.999856 -0.060018  0.482729  0.254233
# VWAP                0.999856  1.000000 -0.060007  0.483068  0.254645
# Volume             -0.060018 -0.060007  1.000000  0.679744  0.648073
# Turnover            0.482729  0.483068  0.679744  1.000000  0.880763
# Trades              0.254233  0.254645  0.648073  0.880763  1.000000
# Deliverable Volume  0.149449  0.149697  0.813342  0.686549  0.659497
# %Deliverble         0.145929  0.146469 -0.211908 -0.137445 -0.179374
#
#                     Deliverable Volume  %Deliverble
# Prev Close                    0.149608     0.147684
# Open                          0.149648     0.147107
# High                          0.153494     0.142298
# Low                           0.145969     0.151544
# Last                          0.149811     0.145808
# Close                         0.149449     0.145929
# VWAP                          0.149697     0.146469
# Volume                        0.813342    -0.211908
# Turnover                      0.686549    -0.137445
# Trades                        0.659497    -0.179374
# Deliverable Volume            1.000000     0.218013
# %Deliverble                   0.218013     1.000000

# %% [markdown]
# # Deliverable Volume and %Deliverable have poor correlation, in this context, we can do imputation for both

# %%
sns.boxplot(df['Deliverable Volume'])
# Out:
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Deliverable Volume'>

# %%
sns.boxplot(df['%Deliverble'])
# Out:
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='%Deliverble'>

# %% [markdown]
# # Althought %Deliverable does not have a lot of outliers, we can stick with using median imputation

# %%
df[['Deliverable Volume', '%Deliverble']] = SI.fit_transform(df[['Deliverable Volume','%Deliverble']])

# %%
df.isna().sum()
# Out:
# Date                  0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %% [markdown]
# # Now that outliers are done, we will shift the focus towards outlier analysis

# %%
for i in df:
    
    if (df[i].dtypes == np.float64) or (df[i].dtypes == np.int64):
        
        plt.figure()
        sns.boxplot(df[i])
# Out:
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\adi07\anaconda3\envs\practice_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.preprocessing import MinMaxScaler

sc = MinMaxScaler()

# %%
df
# Out:
#            Date  Prev Close     Open     High      Low     Last    Close  \
# 0    1996-01-01      204.65   205.00   206.10   203.65   892.35   205.75
# 1    1996-02-01      205.75   205.25   206.25   202.65   892.35   204.15
# 2    1996-03-01      204.15   207.50   216.95   205.25   892.35   205.70
# 3    1996-04-01      205.70   203.75   204.40   201.05   892.35   203.80
# 4    1996-05-01      203.80   203.00   203.00   200.65   892.35   202.40
# ...         ...         ...      ...      ...      ...      ...      ...
# 6200 2020-11-23     1899.50  1951.00  1970.00  1926.25  1955.20  1950.70
# 6201 2020-11-24     1950.70  1964.00  1974.00  1932.00  1971.05  1964.05
# 6202 2020-11-25     1964.05  1980.00  1992.95  1942.20  1947.50  1947.80
# 6203 2020-11-26     1947.80  1953.05  1965.00  1930.05  1957.00  1952.60
# 6204 2020-11-27     1952.60  1940.50  1956.10  1921.40  1940.50  1929.80
#
#          VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# 0      205.26   3717450  7.630000e+13   98415.5           1784092.0
# 1      204.13   6024650  1.230000e+14   98415.5           1784092.0
# 2      207.04   7473500  1.550000e+14   98415.5           1784092.0
# 3      202.47   7744000  1.570000e+14   98415.5           1784092.0
# 4      202.05   5952000  1.200000e+14   98415.5           1784092.0
# ...       ...       ...           ...       ...                 ...
# 6200  1952.18  20918665  4.083700e+15  497781.0           5148955.0
# 6201  1952.11  14277083  2.787040e+15  362587.0           3213843.0
# 6202  1969.06  15062376  2.965870e+15  356793.0           3040444.0
# 6203  1946.67  11924527  2.321310e+15  266412.0           3406506.0
# 6204  1935.45  21845931  4.228160e+15  314085.0          12489338.0
#
#       %Deliverble
# 0          0.4523
# 1          0.4523
# 2          0.4523
# 3          0.4523
# 4          0.4523
# ...           ...
# 6200       0.2461
# 6201       0.2251
# 6202       0.2019
# 6203       0.2857
# 6204       0.5717
#
# [6205 rows x 13 columns]

# %%
df.iloc[:, 1:] = sc.fit_transform(df.iloc[:, 1:])

# %%
df = df.drop(['Date'],axis =1)

# %%
train = df.iloc[0:5974, :]
test = df.iloc[5974:6205, :]

# %%
train
# Out:
#       Prev Close      Open      High       Low      Last     Close      VWAP  \
# 0       0.063539  0.032046  0.031481  0.034208  0.253332  0.033482  0.033405
# 1       0.063881  0.032124  0.031528  0.033879  0.253332  0.032969  0.033040
# 2       0.063384  0.032828  0.034880  0.034734  0.253332  0.033466  0.033980
# 3       0.063865  0.031655  0.030949  0.033353  0.253332  0.032857  0.032504
# 4       0.063275  0.031420  0.030510  0.033222  0.253332  0.032409  0.032369
# ...          ...       ...       ...       ...       ...       ...       ...
# 5969    0.496484  0.456124  0.461079  0.479403  0.470734  0.471254  0.473363
# 5970    0.487884  0.458878  0.459357  0.474373  0.462261  0.463256  0.469516
# 5971    0.480137  0.450351  0.453374  0.463737  0.453066  0.453303  0.460488
# 5972    0.470497  0.445766  0.451259  0.467403  0.461460  0.461942  0.462462
# 5973    0.478864  0.451696  0.451713  0.469622  0.462821  0.462535  0.463938
#
#         Volume  Turnover    Trades  Deliverable Volume  %Deliverble
# 0     0.056225  0.004943  0.066941            0.050244     0.416851
# 1     0.091623  0.008114  0.066941            0.050244     0.416851
# 2     0.113852  0.010286  0.066941            0.050244     0.416851
# 3     0.118003  0.010422  0.066941            0.050244     0.416851
# 4     0.090509  0.007910  0.066941            0.050244     0.416851
# ...        ...       ...       ...                 ...          ...
# 5969  0.175298  0.121957  0.179807            0.135665     0.375942
# 5970  0.125783  0.086656  0.134084            0.116523     0.466186
# 5971  0.207937  0.140964  0.144051            0.164900     0.387140
# 5972  0.123182  0.083941  0.110462            0.075345     0.280488
# 5973  0.119298  0.081226  0.097501            0.086242     0.346120
#
# [5974 rows x 12 columns]

# %%
X_train = train.drop(['Close'], axis=1)
Y_train = train[['Close']]

# %%
X_test = test.drop(['Close'], axis =1)
Y_test = test[['Close']]

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_train.shape, X_test.shape
# Out:
# ((5974, 11, 1), (231, 11, 1))

# %% [markdown]
# # Building LSTM model

# %%
import tensorflow as tf 
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout

# %%
model = Sequential()
model.add(LSTM(units = 100, return_sequences = True, input_shape = (X_train.shape[1],1)))
model.add(LSTM(units = 50, return_sequences = False))
model.add(Dense(25, activation = 'sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
history = model.fit(X_train, Y_train, batch_size = 64, epochs = 10, validation_data = (X_test, Y_test))
# Out:
# Epoch 1/10
# 94/94 [==============================] - 5s 24ms/step - loss: 0.0779 - val_loss: 0.1039
# Epoch 2/10
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0362 - val_loss: 0.0927
# Epoch 3/10
# 94/94 [==============================] - 2s 17ms/step - loss: 0.0340 - val_loss: 0.0582
# Epoch 4/10
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0109 - val_loss: 5.3014e-04
# Epoch 5/10
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0041 - val_loss: 7.2513e-04
# Epoch 6/10
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 7/10
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 8/10
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0020 - val_loss: 5.1461e-04
# Epoch 9/10
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 10/10
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0014 - val_loss: 2.7719e-04

# %%
plt.plot(history.history['loss'], label ='train')
plt.plot(history.history['val_loss'], label = 'test')
plt.legend()

# %%
y_pred = model.predict(X_test)
# Out:
# 8/8 [==============================] - 1s 5ms/step

# %%
y_pred
# Out:
# array([[0.4587268 ],
#        [0.44827417],
#        [0.4519425 ],
#        [0.4582425 ],
#        [0.45482105],
#        [0.45085132],
#        [0.45137176],
#        [0.4560868 ],
#        [0.46059674],
#        [0.46222857],
#        [0.45828235],
#        [0.45582503],
#        [0.45459116],
#        [0.4702241 ],
#        [0.4775966 ],
#        [0.45698428],
#        [0.456165  ],
#        [0.45457754],
#        [0.45364594],
#        [0.44897103],
#        [0.44669145],
#        [0.43909022],
#        [0.43546036],
#        [0.42948893],
#        [0.41222835],
#        [0.40824094],
#        [0.4151532 ],
#        [0.4235233 ],
#        [0.42755204],
#        [0.42429084],
#        [0.41987574],
#        [0.4262518 ],
#        [0.4303388 ],
#        [0.43375137],
#        [0.43820167],
#        [0.43911454],
#        [0.43306798],
#        [0.43867436],
#        [0.44455963],
#        [0.4357446 ],
#        [0.42807811],
#        [0.41660526],
#        [0.4079807 ],
#        [0.40205222],
#        [0.39349532],
#        [0.39041537],
#        [0.39188093],
#        [0.3932737 ],
#        [0.3758397 ],
#        [0.36757421],
#        [0.33543274],
#        [0.32514596],
#        [0.3149087 ],
#        [0.30944103],
#        [0.30240396],
#        [0.29469976],
#        [0.27906403],
#        [0.28696898],
#        [0.27473828],
#        [0.27084807],
#        [0.30559114],
#        [0.3182239 ],
#        [0.31555632],
#        [0.3032201 ],
#        [0.31453606],
#        [0.3216164 ],
#        [0.3215504 ],
#        [0.3345688 ],
#        [0.3524034 ],
#        [0.35171026],
#        [0.34709862],
#        [0.34656993],
#        [0.33804122],
#        [0.35025215],
#        [0.3585445 ],
#        [0.36375505],
#        [0.42002165],
#        [0.41395453],
#        [0.44603407],
#        [0.43504077],
#        [0.44047228],
#        [0.42842156],
#        [0.44674024],
#        [0.43816376],
#        [0.43713647],
#        [0.43922493],
#        [0.44570506],
#        [0.4837817 ],
#        [0.4913465 ],
#        [0.4886208 ],
#        [0.45980108],
#        [0.44521973],
#        [0.43902805],
#        [0.44448113],
#        [0.43100423],
#        [0.42751393],
#        [0.4301099 ],
#        [0.43117705],
#        [0.42822683],
#        [0.42733657],
#        [0.43866295],
#        [0.4414678 ],
#        [0.4497632 ],
#        [0.4560752 ],
#        [0.46307778],
#        [0.47023723],
#        [0.48163608],
#        [0.48241276],
#        [0.4684113 ],
#        [0.4646083 ],
#        [0.46632615],
#        [0.4651335 ],
#        [0.48764092],
#        [0.4992067 ],
#        [0.49377576],
#        [0.49796233],
#        [0.5481127 ],
#        [0.55217195],
#        [0.5352363 ],
#        [0.53799015],
#        [0.5314997 ],
#        [0.5292746 ],
#        [0.5271665 ],
#        [0.52670735],
#        [0.5248115 ],
#        [0.5332876 ],
#        [0.54287857],
#        [0.5624493 ],
#        [0.56674135],
#        [0.555039  ],
#        [0.55627644],
#        [0.570093  ],
#        [0.6009402 ],
#        [0.60415083],
#        [0.6364251 ],
#        [0.57617337],
#        [0.5792646 ],
#        [0.5883951 ],
#        [0.6003152 ],
#        [0.62049466],
#        [0.6335721 ],
#        [0.7097    ],
#        [0.7025798 ],
#        [0.68217725],
#        [0.69011253],
#        [0.66928643],
#        [0.67016715],
#        [0.63210195],
#        [0.6684667 ],
#        [0.69259715],
#        [0.66607565],
#        [0.6549804 ],
#        [0.65332276],
#        [0.66171587],
#        [0.6492799 ],
#        [0.6468626 ],
#        [0.6497684 ],
#        [0.64016163],
#        [0.64119166],
#        [0.65360314],
#        [0.6414002 ],
#        [0.6388955 ],
#        [0.6383908 ],
#        [0.63376397],
#        [0.65802634],
#        [0.6505138 ],
#        [0.6446661 ],
#        [0.6708086 ],
#        [0.6430345 ],
#        [0.6410302 ],
#        [0.64270157],
#        [0.63872665],
#        [0.63091815],
#        [0.6381216 ],
#        [0.6631032 ],
#        [0.78919256],
#        [0.758107  ],
#        [0.74381834],
#        [0.7210186 ],
#        [0.73816526],
#        [0.7238303 ],
#        [0.7254927 ],
#        [0.721831  ],
#        [0.7027787 ],
#        [0.7025597 ],
#        [0.68013746],
#        [0.6710813 ],
#        [0.6750268 ],
#        [0.68542945],
#        [0.6908279 ],
#        [0.68619233],
#        [0.679073  ],
#        [0.6749682 ],
#        [0.71740466],
#        [0.690112  ],
#        [0.68244237],
#        [0.6786009 ],
#        [0.69177556],
#        [0.710412  ],
#        [0.69383055],
#        [0.6717469 ],
#        [0.67285705],
#        [0.65892684],
#        [0.661489  ],
#        [0.64921314],
#        [0.6416693 ],
#        [0.64097345],
#        [0.6245628 ],
#        [0.62158984],
#        [0.6151563 ],
#        [0.62447655],
#        [0.64600354],
#        [0.6006039 ],
#        [0.5936969 ],
#        [0.59768784],
#        [0.62792814],
#        [0.62938917],
#        [0.63598186],
#        [0.64348394],
#        [0.612443  ],
#        [0.6171169 ],
#        [0.6015883 ],
#        [0.62951356],
#        [0.6082014 ],
#        [0.60600233],
#        [0.61036175],
#        [0.5998554 ],
#        [0.5986437 ],
#        [0.6023004 ],
#        [0.5943701 ],
#        [0.6021081 ]], dtype=float32)

# %%
X_test.shape[0]
# Out:
# 231

# %%
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1])
data = np.concatenate((X_test, y_pred), axis = 1)
inv_data = sc.inverse_transform(data)
y_pred = inv_data[:,-1]

# %%
plt.figure()
plt.plot(df.Close)
index = list(range(5974,6205))
plt.plot(index, y_pred, label = 'LSTM predicted')
plt.legend()
